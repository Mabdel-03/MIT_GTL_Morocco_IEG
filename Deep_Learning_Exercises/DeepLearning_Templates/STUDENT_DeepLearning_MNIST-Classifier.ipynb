# %% [markdown]
# # Exercise: Building Two Deep Learning Models For Handwritten Text Classification!
#
# The MNIST dataset consists of images of handwritten letters, alongside labels of what the letters are. Your objective is to build and train two deep learning models using Pytorch, using the MNIST dataset for text classification, then compare the classification accuracy of the two models. The first model should bea simple multilayer perceptron, and the second should be a convolutional neural network. You have full autonomy over the hyperparameters, but after getting reasonable results (at least one model should get >95% accuracY) you need to explain why the model that did better was able to perform better. Good luck!
#
# P.S: Make sure you use a GPU runtime (change runtime in the upper right hand corner of the Colab, T4 runtime should be good enough). If you don't do this, training will take a very long time!

# %% [markdown]
# # Imports + Load Data (Load MNIST data, convert to tensors, split into train and test data)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transform, download=True)

train_loader = DataLoader(dataset=train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# # Your Code!
